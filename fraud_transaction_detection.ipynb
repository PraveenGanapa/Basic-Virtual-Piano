# %% [markdown]
# <a href="https://colab.research.google.com/github/PraveenGanapa/Basic-Virtual-Piano/blob/master/fraud_transaction_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import  pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
credit_card_data = pd.read_csv('/content/creditcard.csv')

# %%
credit_card_data.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0     0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1     0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2     1 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3     1 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4     2 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
credit_card_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27819 entries, 0 to 27818
# Data columns (total 31 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Time    27819 non-null  int64
#  1   V1      27818 non-null  float64
#  2   V2      27818 non-null  float64
#  3   V3      27818 non-null  float64
#  4   V4      27818 non-null  float64
#  5   V5      27818 non-null  float64
#  6   V6      27818 non-null  float64
#  7   V7      27818 non-null  float64
#  8   V8      27818 non-null  float64
#  9   V9      27818 non-null  float64
#  10  V10     27818 non-null  float64
#  11  V11     27818 non-null  float64
#  12  V12     27818 non-null  float64
#  13  V13     27818 non-null  float64
#  14  V14     27818 non-null  float64
#  15  V15     27818 non-null  float64
#  16  V16     27818 non-null  float64
#  17  V17     27818 non-null  float64
#  18  V18     27818 non-null  float64
#  19  V19     27818 non-null  float64
# ...

# %%
credit_card_data.isnull().sum()
# Out:
# Time      0
# V1        1
# V2        1
# V3        1
# V4        1
# V5        1
# V6        1
# V7        1
# V8        1
# V9        1
# V10       1
# V11       1
# V12       1
# V13       1
# V14       1
# V15       1
# V16       1
# V17       1
# V18       1
# V19       1
# V20       1
# V21       1
# V22       1
# V23       1
# V24       1
# V25       1
# V26       1
# V27       1
# V28       1
# Amount    1
# Class     1
# dtype: int64

# %%
credit_card_data['Class'].value_counts()
# Out:
# 0.0    27725
# 1.0       93
# Name: Class, dtype: int64

# %%
legit = credit_card_data[credit_card_data.Class == 0]
fraud = credit_card_data[credit_card_data.Class == 1]

# %%
print(legit.shape)
print(fraud.shape)
# Out:
# (27725, 31)
# (93, 31)

# %%
legit.Amount.describe()
# Out:
# count    27725.000000
# mean        77.232517
# std        219.509762
# min          0.000000
# 25%          6.490000
# 50%         19.950000
# 75%         69.320000
# max       7879.420000
# Name: Amount, dtype: float64

# %%
fraud.Amount.describe()
# Out:
# count      93.000000
# mean       96.609677
# std       259.128010
# min         0.000000
# 25%         1.000000
# 50%         1.100000
# 75%        99.990000
# max      1809.680000
# Name: Amount, dtype: float64

# %%
credit_card_data.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    20440.754518 -0.190595  0.129284   0.765200  0.201632 -0.180681
# 1.0    18829.451613 -8.165086  6.134379 -11.690379  6.070066 -5.753486
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.092904 -0.099318  0.014884  0.405538  ...  0.041673 -0.037007
# 1.0   -2.388962 -7.986805  4.121062 -2.922478  ...  0.697894  0.549621
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.125822 -0.040202  0.011510  0.129192  0.022983  0.010650  0.003732
# 1.0   -0.372248 -0.340859 -0.260055  0.359772  0.179521  0.832824  0.100500
#
#           Amount
# Class
# 0.0    77.232517
# 1.0    96.609677
#
# [2 rows x 30 columns]

# %%
legit_sample = legit.sample(n=492)

# %%
new_dataset = pd.concat([legit_sample, fraud], axis=0)

# %%
new_dataset.head()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 7509   10254 -0.366698  0.668497  2.368016  1.242119 -0.224208  1.093536
# 22465  32260  0.928109 -0.416534  1.273992  1.861894 -1.004141  0.411151
# 23323  32698 -1.341888  0.284113  1.887340  0.172680  1.268763  0.153436
# 6798    8565 -1.384305  1.039127  1.957868 -1.631141  0.529895  0.250339
# 4704    4129 -0.766312  0.579711  2.316592  1.442345 -0.359837 -0.343325
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 7509  -0.312947  0.428233  1.327611  ... -0.046134  0.302239 -0.095643
# 22465 -0.489297  0.287882  1.336329  ... -0.362564 -0.755340  0.075082
# 23323  0.786326 -0.006910 -0.409335  ... -0.065160  0.097334 -0.154253
# 6798   0.897775 -0.468799  2.704753  ... -0.461666 -0.161372 -0.070448
# 4704   0.120095  0.017702  1.399369  ...  0.083819  0.700013 -0.022721
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset.tail()
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 26802  34256  0.539276  1.554890 -2.066180  3.241617  0.184736  0.028330
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
#
#              V7        V8        V9  ...       V21       V22       V23  \
# 26802 -1.515521  0.537035 -1.999846  ...  0.371773  0.111955 -0.305225
# 27362 -0.123372  0.223122 -0.673598  ... -0.159387 -0.305154  0.053620
# 27627 -2.275789  0.675229 -2.042416  ...  0.469212 -0.144363 -0.317981
# 27738 -2.206056 -2.282725 -0.292885  ...  1.774460 -0.771390  0.065727
# 27749 -5.479117  1.189472 -3.908206  ...  1.192694  0.090356 -0.341881
#
#             V24       V25       V26       V27       V28  Amount  Class
# ...

# %%
new_dataset['Class'].value_counts()
# Out:
# 0.0    492
# 1.0     93
# Name: Class, dtype: int64

# %%
new_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2         V3        V4        V5  \
# Class
# 0.0    21290.670732 -0.236962  0.202334   0.735325  0.155484 -0.101617
# 1.0    18829.451613 -8.165086  6.134379 -11.690379  6.070066 -5.753486
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0.0    0.068254 -0.103418  0.005166  0.389977  ... -0.007302 -0.007302
# 1.0   -2.388962 -7.986805  4.121062 -2.922478  ...  0.697894  0.549621
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0.0   -0.139151  0.011918  0.044850  0.120968  0.042984  0.023031  0.004582
# 1.0   -0.372248 -0.340859 -0.260055  0.359772  0.179521  0.832824  0.100500
#
#           Amount
# Class
# 0.0    62.922581
# 1.0    96.609677
#
# [2 rows x 30 columns]

# %%
X = new_dataset.drop(columns='Class', axis=1)
Y = new_dataset['Class']

# %%
print(X)
# Out:
#         Time        V1        V2        V3        V4        V5        V6  \
# 7509   10254 -0.366698  0.668497  2.368016  1.242119 -0.224208  1.093536
# 22465  32260  0.928109 -0.416534  1.273992  1.861894 -1.004141  0.411151
# 23323  32698 -1.341888  0.284113  1.887340  0.172680  1.268763  0.153436
# 6798    8565 -1.384305  1.039127  1.957868 -1.631141  0.529895  0.250339
# 4704    4129 -0.766312  0.579711  2.316592  1.442345 -0.359837 -0.343325
# ...      ...       ...       ...       ...       ...       ...       ...
# 26802  34256  0.539276  1.554890 -2.066180  3.241617  0.184736  0.028330
# 27362  34521  1.081234  0.416414  0.862919  2.520863 -0.005021  0.563341
# 27627  34634  0.333499  1.699873 -2.596561  3.643945 -0.585068 -0.654659
# 27738  34684 -2.439237  2.591458 -2.840126  1.286244 -1.777016 -1.436139
# 27749  34687 -0.860827  3.131790 -5.052968  5.420941 -2.494141 -1.811287
#
#              V7        V8        V9  ...       V20       V21       V22  \
# ...

# %%
print(Y)
# Out:
# 7509     0.0
# 22465    0.0
# 23323    0.0
# 6798     0.0
# 4704     0.0
#         ...
# 26802    1.0
# 27362    1.0
# 27627    1.0
# 27738    1.0
# 27749    1.0
# Name: Class, Length: 585, dtype: float64

# %%
X_train, X_test, Y_train, Y_test, = train_test_split(X, Y, test_size=0.2, stratify=Y, random_state=2)

# %%
print(X.shape, X_train.shape, X_test.shape)
# Out:
# (585, 30) (468, 30) (117, 30)

# %%
modal = LogisticRegression()

# %%
modal.fit(X_train, Y_train)

# %%
X_train_prediction = modal.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction, Y_train)

# %%
print('accuracy on training data :', training_data_accuracy)
# Out:
# accuracy on training data : 0.9807692307692307

# %%
X_test_prediction = modal.predict(X_test)
test_data_accuracy = accuracy_score(X_test_prediction, Y_test)

# %%
print('accuracy score on test data :',test_data_accuracy)
# Out:
# accuracy score on test data : 0.9829059829059829
